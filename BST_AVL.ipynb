# %% [markdown]
# <a href="https://colab.research.google.com/github/shlin101204/colab/blob/main/BST_AVL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 視覺化互動式二元搜尋樹(以 Python實現)
# 本程式參考 Prof. E. Kiss, HS KL所發佈之 [BSTLearner - An interactive visualization of binary search trees](https://www.evamariakiss.de/apps/bstlearner.php)，依其程式修改及修正錯誤，並加入高度平衡樹(AVL Tree)程式碼，及增加步進式互動過程，以期使用者可以詳細瞭解每一步驟。
#
# ✉ [shlin@ctust.edu.tw](mailto:shlin@ctust.edu.tw)

# %% [markdown]
# # 樹(Tree)-資料結構
# 在計算機科學中，樹」是一種重要而且經常使用的「資料結構」，其屬於延伸性的資料結構，生活中常見的例子有家族族譜、公司組織圖、比賽賽程、決策模型及目錄等。把它叫做「樹」是因為結構上看起來就像一棵倒過來的樹，結構就像樹枝(branch)與樹葉(leaf)的關係一樣。
#
# 於計算機科技中的應用也很廣泛，例如二元搜尋樹之資料結構即可用於資料搜尋，可以說是學習程式設計及演算法中重要的課題。而有關於二元搜尋樹的運算，包含樹之建立、插入新節點、刪除節點及搜尋節點，它們的效率皆取決於樹的高度。而為了維持二元搜尋樹的樹高度於最小，有一演算法可以動態調整二元搜尋樹使其高度維持最低，此即為高度平衡樹(AVL tree)。

# %% [markdown]
# # 樹狀結構
#
# ## 【定義】
# 樹狀結構是由一個或多個節點組合而成的有限集合，它必須要滿足以下兩點：
# Tree(樹)不可以為空，至少有一個節點稱為Root(根節點)。
# 其餘的節點分成T1 , T2,.....,Tn個互斥集合。因此，我們也可以稱T1 , T2,....., Tn 為根節點的子樹 ( Sub tree ) 。

# %% [markdown]
# #樹狀結構
# 【定義】
# 樹狀結構是由一個或多個節點組合而成的有限集合，它必須要滿足以下兩點： Tree(樹)不可以為空，至少有一個節點稱為Root(根節點)。 其餘的節點分成T1 , T2,.....,Tn個互斥集合。因此，我們也可以稱T1 , T2,....., Tn 為根節點的子樹 ( Sub tree ) 。
#
# ![31484.jpg](data:image/jpeg;base64,...)
#
# ## 【特性】
# *   每個節點都只有有限個子節點或無子節點。
# *   沒有父節點的節點稱為根節點。
# *   每一個非樹根節點有一個且只有一個父節點。
# *   除了樹根節點外，每個子節點可以分為多個不相交的子樹。
# *   樹裡面沒有環路(cycle)。
#
# ## 【名辭】
# *   節點 (Node)：樹狀結構中每一個資料元素都稱為節點。
# *   分支度 (Dregree)：每個節點所擁有的分支數。
# *   根節點 (Root)：根節點具有唯一性，是整個樹狀結構最上層的樹根。
# *   葉節點 (Leaf)：節點之下都沒有子節點稱為葉節點(像樹葉的葉子)，或稱為終端節點，即分支度為零的節點。
# *   非終端點 (Non-terminal Nodes)：除了葉節點外的其他節點，即分支度不為零的節點。
# *   父節點 (Parent)與子節點 (Child)：被分支的節點上方一個節點稱為此節點的父節點，而節點向下分支出的節點稱為子節點。如同父子關係般，父節點通常只有一個，子節點可以有一個或多個。
# *   兄弟節點 (Siblings)：同一個父節點的其他節點，稱為兄弟節點。
# *   階層 (Level)：從樹根開始，向下延伸的層級。
# *   樹高(Height):樹的最大階層即為樹的高度。

# %% [markdown]
# # 樹的種類
#
# *   無序樹：樹中任意節點與子節點之間沒有順序關係，這種樹稱為無序樹。
# *   有序樹：相對的如果樹中任意節點與子節點之間有順序關係，這種樹稱為有序樹。
#
#
# *   二元樹：樹中每個節點最多只有兩個子樹，即每一個節點最多只分支出2個子節點，亦即分支度小於或等於 2 的樹稱為二元樹。
#
#
# *   完滿二元樹(Full Binary Tree)：如果樹的高度是 k 節點，那節點的個數就是 2 的 k - 1 次方，是具有最多節點的二元樹。除了葉節點外，每個節點都有兩個子節點。
#
#
# ![f3.png](data:image/png;base64,...)
#
# *   完整二元樹(Complete Binary Tree)：對於一棵二元樹，假設其深度為d（d>1）。除了第d層外，其它各層的節點數目均已達最大值，且第d層所有節點從左向右連續地緊密排列，這樣的二元樹被稱為完全二元樹；
#
# ![f4.png](data:image/png;base64,...)
#
#
# *   二元搜尋樹(Binary Search Tree)：也稱為有序二元樹（ordered binary tree）或排序二元樹（sorted binary tree），是指一棵空樹或者具有下列性質的二元樹：
# ![f5.jpg](data:image/jpeg;base64,...)
#
# *   高度平衡二元樹（AVL tree）：若且唯若任何節點的兩棵子樹的高度差不大於1的二元樹；即每一個節點的的左邊子節點的高度-右邊子節點的高度只能是 -1、0、1，所以 AVL樹 也是平衡樹的一種，此特性讓整個樹不會長歪，在搜尋時的速度會更快。
#
# ![f6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 二元搜尋樹(Binary Search Tree)
#
# 也稱為有序二元樹（ordered binary tree）或排序二元樹（sorted binary tree），是指一棵空樹或者具有下列性質的二元樹：
#
# *   若任意節點的左子樹不空，則左子樹上所有節點的值均小於它的根節點的值；
# *   若任意節點的右子樹不空，則右子樹上所有節點的值均大於它的根節點的值；
# *   任意節點的左、右子樹也分別為二元搜尋樹；

# %% [markdown]
# # 高度平衡二元樹（AVL tree）
#
# 有關於二元搜尋樹的運算，包括二元搜尋樹的建立、插入新節點、刪除節點、搜尋節點等，他們的效率都取決於樹的高度，因此如果二元樹愈趨近於完滿，高度會愈小。
# 當我們對二元搜尋樹進行動態存取維護，在再次插入或刪除時，只著眼於保持二元搜尋樹的性質，並沒有去考慮高度的問題。可以預見的是，經過一段時問的存取之後，二元樹的高度可能越來越大，因為我們根本沒去控制它。
#
# 為了使樹的高度趨於最小，而使動態存取維護的效率保恃在O(lgn)在每次插入和刪除之後，必要時要對二元樹做一些高度調整。因此Adelson Velsk和Landis二人提出高度平衡二元樹（由於兩人的名字，因此又稱為AVL樹）。
#
# 【定義】：
# 1.	一個空的樹為高度平衡二元樹。
# 2.	如果T是一個非空二元樹，且TL和TR分別為其左、右子樹，則 T 為高度平衡二元樹
#
# 1.	T<sub>L</sub>，T<sub>R</sub>為高度平衡。 且
# 2.	hL-hR 的絕對值 ≦ 1，其中 h<sub>L </sub>,h<sub>R</sub> 分別為 T<sub>L</sub>，T<sub>R</sub>高度。
#
# ![f15.jpg](data:image/jpeg;base64,...)
#
# 例如圖1-(a)，每一個內部節點左右子樹高度相差最多足l，因此是AVL樹。
# 圖1-(b)不是AVL樹。
#
# 每個節點的平衡係數(Balance factor,BF)定義是：此節點的hL-hR。所以在AVL樹中，每個節點的平衡係數均為l或0或-l。
#
# 果能夠在每次的插入和刪除之後，保持二元搜尋樹仍為AVL樹，將可使動態存取的效率保持在O(lgn)。調整的方法，必須透過旋轉。
# 假設新加入節點為N，而由於新節點的加入，造成原本平衡係數BF為+1的節點其BF變為+2，則違反了AVL性質。這時，就必須根據新節點插入的位置，分成四種LL型狀況來旋轉調整，使其恢復AVL性質。
#
# 1.   LL型:新節點N插入到節點A的左兒子的左子樹。
# 2.   RR型:新節點N插入到節點A的右兒子的右子樹。
# 3.   LR型:新節點N插入到節點A怕左兒了的右子樹。
# 4.   RL型:新節點N插入到節點A的右兒子的左子樹。
#
# #【LL型】
#
# 由於新節點N加在節點A的左兒子(節點B)的左子樹，造成B和A的平衡係數BF都加l。因此調整的方法是作一次順時針旋轉，將節點B順時針旋轉為此子樹的新樹根，節點A順時針旋轉成節點B的右兒子。由於節點B的右子樹BR原本就介於B、A兩者之間，因此將BR移至節點A的左子樹。注意這樣的旋轉，使得結果仍符合二元搜尋樹的性質，同時高度也重新平衡。上圖是LL型旋轉的示意圖。
#
# ![f7.jpg](data:image/jpeg;base64,...)
#
# #【RR型】
#
# RR型其實對稱於LL型旋轉。新節點N加在節點A的右兒子(節點B)的右子樹，造成B和A的平衡係數BF都減l。因此調整的方法是作一次逆時針旋轉，將節點B逆時針旋縛為此子樹的新樹根，節點A逆時針旋轉成節點B的左兒子。由於節點B的左子樹BL原本就介於B、A兩者之間，因此將BL移至節點A的右子樹。這樣的旋轉，使得結果仍符合二元搜尋樹的性質，同時高度也重新平衡。上圖是RR型旋轉的示意圖。
#
#
# ![f8.jpg](data:image/jpeg;base64,...)
#
# #【LR型】
#
# 新節點N加在節點A的左兒子(節點B)的右子樹，造成A的平衡係數BF加l，節點B的平衡係數BF減l。觀察二元搜尋樹的次序關係，發現可以用節點C為新樹根。由於節點C的右子樹CR原本就介於C、A兩者之間，因此將CR移至節點A的左子樹。由於節點C的左子樹CL原本就介於B、C兩者之間，因此將CL移至節點B的右子樹。上圖是LR型旋轉的示意圖。
#
# ![f9.jpg](data:image/jpeg;base64,...)
#
# #【RL型】
#
#
# RL型對稱於LR型旋轉。新節點N加在節點A的右兒子(節點B)的左子樹，造成A的平衡係數BF減l，節點B的平衡係數BF加l。用節點C為新樹根。由於節點C的右子樹CR原木就介於C、B兩者之間，因此將CR移至節點B約左子樹。由於節點C的左子樹CL原本就介於A,C兩名之間，因此將CL移至節點A的右子樹。上圖是RL型旋轉的示意圖。
#
# 由四種情形可以得知，所有不平衡之狀況皆可以重新獲得平衡，故而AVL樹以此四種旋轉方式必然可以攸不平衡樹重新獲得平衡。
#
#
# ![f10.jpg](data:image/jpeg;base64,...)
#
# Example：資料插入順序 8 ,5,3,1,2,10,12,16,4,14
#
# ![f11.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from numpy.random import seed, randint
import ipywidgets as widgets 
from ipywidgets import BoundedIntText, Button, HTML, Tab, HBox, VBox, Output, Layout
from IPython.display import display, clear_output, SVG, HTML
import graphviz as gv # for visualizing a tree using Digraph
from graphviz import Digraph
import pydot
from IPython.core.display import DisplayObject
import time

###############
#除錯功能: debug(msg)
#     用於除錯時輸出除錯訊息，如果 outputdebug= True 時，
#     即於螢幕顯示除錯訊息(msg)
#     msg : 欲顯示之除錯訊息
###############

outputdebug = False

def debug(msg):
  if outputdebug:
    print(msg)
kind_of_tree = 1  #二元樹種類: 0:二元搜尋樹(BST), 1:高度平衡樹 (AVL Tree)
bf = 0 #平衡係數 (balance fcator)

# %% [markdown]
# # 定義樹節點類別 (class TreeNode)
# TreeNode 節點類別有四個主要屬性：
#
# *   key：節點之鍵值，此例中的鍵值為正整數
# *   parent：節點之父節點鏈結
# *   left：節點之左子節點鏈結
# *   right：節點之左子節點鏈結
#
# 另外用於顯示樹的結構於螢幕時使用的輔助屬性有以下三個：
#
# *   pos：節點於圖中的位置 [x,y]
# *   col：節點顏色(正常為 black，插入節點之父節點位置為 red)
# *   h：節點於樹中的高度

# %%
class TreeNode:
  def __init__(self, key):
    self.key = key
    self.parent = None
    self.left = None
    self.right = None
    self.pos = [0, 0] # 節點於圖中的位置 [x,y]
    self.col = "black" # 節點顏色
    self.h = 0 # 節點所在子樹高度
  def spos(self):
    ''' 以 neato 格式呈現節點於圖中的位置 for x,y! '''
    return str(self.pos[0]) + "," + str(self.pos[1]) + "!"
  def to_string(self):
    return str(self.key)
  def print(self):        
    print("TreeNode: %d" % (self.key))

# %% [markdown]
# 定義二元搜尋樹類別 (class BST())
#
# 定義二元搜尋樹三個主要方法(method)：
#
#
# *   insert(self, k):插入鍵值為 k 的節點到二元搜尋樹中
# *   search(self, x, k)：由節點 x 開始尋找鍵值為 k 的節點
# *   delete(self, k)：刪除鍵值為 k 的節點

# %%
class BST():
  global kind_of_tree
  def __init__(self):
    self.root = None # Root of the tree
    self.list = [] # Elements of the tree as list
  # Insert a key 
  def insert(self, k):
    ''' 插入鍵值為 k 的節點到二元搜尋樹中 '''
    newNode = TreeNode(k)
    # If the tree is empty, the new node is the root
    if self.root == None:
      self.root = newNode
    else:        
      x = self.root
      # 尋找節點的父節點
      while x != None:
        p = x
        if newNode.key < x.key:
          x = x.left
        elif newNode.key >= x.key:
          x = x.right
      # Set parent, left and right child for newNode 
      newNode.parent = p       
      if newNode.key < p.key:
        p.left = newNode
      else: 
        p.right = newNode
      dot = BSTViz(self).visualize(newNode)
      display(dot)

  def search(self, x, k):
    ''' 由節點 x 開始尋找鍵值為 k 的節點  '''
    if ( x== None):
      print("找不到鍵值 " + str(k))
      return x
    if (x.key == k):
      return x
    if (k < x.key):
      return self.search(x.left, k)
    else: 
      return self.search(x.right, k)
  
  def find(self, k):  
    return self.search(self.root, k)   
    
  def transplant(self, u, v):
    ''' 取代子樹 u 為子樹 v '''
    if (u.parent == None):
      self.root = u
    elif u == u.parent.left:
      u.parent.left = v
    else:
      u.parent.right = v
    if v != None:
      v.parent = u.parent
            
  def tree_minimum(self, x):
    ''' 找到子樹 x 中的最小鍵值節點 '''
    while (x.left != None):
      x = x.left
    return x;

  def delete(self, k):
    '''刪除鍵值為 k 的節點 ''' 
    z = self.search(self.root, k)
    if z == None:
      debug("找不到鍵值 " + str(k))
      return
    else:
      debug("刪除鍵值 " + str(k))
    if z.left == None: # case 1: z has no left child
      self.transplant(z, z.right)
    elif z.right == None: # case 2: z has no right child
      self.transplant(z, z.left)
    else: 
      y = self.tree_minimum(z.right) # determine smallest value in z.right
      if (y.parent != z):
        self.transplant(y, y.right)
        y.right = z.right
        y.right.parent = y
      self.transplant(z, y)
      y.left = z.left
      y.left.parent = y
      if (z == self.root):
        self.root = y
                       

  def height(self, x):
    if (x == None):
      return 0
    else: 
      return 1 + np.maximum(self.height(x.left),  self.height(x.right))
    
  def inorder_traversal(self, x):
    '''Inorder traversal of the tree: returns elements sorted by key '''
    if (x != None):
      if (x == self.root):
        self.list = []
      self.inorder_traversal(x.left)
      self.list.append(x.to_string())
      self.inorder_traversal(x.right)

  def rotate_left(self, x):
    ''' Rotate left on node x'''
    print(str(x.key) + ' 向左旋轉')
    y = x.right # set y to be right child
    # turn y's left subtree to x's right subtree
    x.right = y.left
    if y.left != None:
      y.left.parent = x
    y.parent = x.parent # link x's parent to y
    if x.parent == None: # Case 1: x is root
      self.root = y
    elif x == x.parent.left: # Case 2: x is left child
      x.parent.left = y
    else: # Case 3: x is right child
      x.parent.right = y
    y.left = x
    x.parent = y

  def rotate_right(self, x):
    ''' Rotate right on node x'''
    print(str(x.key) + '  向右旋轉')
    y = x.left # set y to be left child
    # turn y's right subtree to x's left subtree
    x.left = y.right
    if y.right != None:
      y.right.parent = x
    y.parent = x.parent # link x's parent to y
    if x.parent == None: # Case 1: x is root
      self.root = y
    elif x == x.parent.right: # Case 2: x is right child
      x.parent.right = y
    else: # Case 3: x is left child
      x.parent.left = y
    y.right = x
    x.parent = y

  def postorder_traversal(self, x):
    '''Postorder traversal of the tree: left child, right child, root '''
    if (x != None):
      if (x == self.root):
        self.list = []
      self.postorder_traversal(x.left)
      self.postorder_traversal(x.right)
      self.list.append(x.to_string())
  def preorder_traversal(self, x):
    '''Preorder traversal of the tree: root, left child, right child '''
    if (x != None):
      if (x == self.root):
        self.list = []
      self.list.append(x.to_string())
      self.preorder_traversal(x.left)
      self.preorder_traversal(x.right)

# %%
class BSTViz: 
  def __init__(self, bst):
    self.bst = bst
  def visualize(self, node):   
    ''' Visualize the tree using graphviz '''
    tree = self.bst.root # start with root of the tree 
    dot = Digraph()
    dot.engine = 'neato'
    # Place root node at position tree.pos 
    h = self.bst.height(tree)
    bf = self.bst.height(tree.left) - self.bst.height(tree.right)
    tree.pos = [0, h]
    if kind_of_tree == 0 :
      lbl = str(tree.key)
    else:
      lbl = str(tree.key) +":" + str(bf)
    dot.node(name=str(tree), label=lbl, color = tree.col, shape="circle", 
        fixedsize="True", width="0.45", pos = tree.spos())
    # Recursively place the other nodes and edges              
    def add_nodes(tree, dot):
      col = "black"
      if tree.left: # if left subtree: position node to left of parent
        if node != None and tree.left.key == node.key :
          col= "green"
        h = self.bst.height(tree.left)            
        bf = self.bst.height(tree.left.left) - self.bst.height(tree.left.right)
        tree.left.pos[0] = tree.pos[0] - h # x
        tree.left.pos[1] = tree.pos[1] - 0.6 # y       
        if kind_of_tree == 0 :
          lbl = str(tree.left.key)
        else:
          lbl = str(tree.left.key) +":" + str(bf)
        dot.node(name=str(tree.left), label=lbl, color = col,
            shape="circle", fixedsize="True", width="0.45", pos=tree.left.spos())
        dot.edge(str(tree), str(tree.left))
        dot = add_nodes(tree.left, dot=dot)
        col = "black"
      if tree.right: # if right subtree: position node to right of parent
        if node != None and tree.right.key == node.key :
          col = "red"
        h = self.bst.height(tree.right)                    
        bf = self.bst.height(tree.right.left) - self.bst.height(tree.right.right)
        if kind_of_tree == 0 :
          lbl = str(tree.right.key)
        else:
          lbl = str(tree.right.key) +":" + str(bf)
        tree.right.pos[0] = tree.pos[0] + h # x
        tree.right.pos[1] = tree.pos[1] - 0.6 # y                
        dot.node(name=str(tree.right), label=lbl, color = col,
            shape="circle", fixedsize="True", width="0.45", pos=tree.right.spos())
        dot.edge(str(tree), str(tree.right))
        dot = add_nodes(tree.right, dot=dot)
        col="black"                    
      return dot 
    return add_nodes(tree, dot)

# %%
class AVLTree(BST): 
  def __init__(self):
    super().__init__()
  
  def insert(self, k):
    ''' Insert a key '''
    super().insert(k)
    p = super().find(k) 
    prevBalance = 0
    while (p != None):
      bf = super().height(p.left) - super().height(p.right)
      debug(str(p.key)+" 的平衡係數:"+str(bf))
      if (bf > 1 and prevBalance > 0): # Case 1 LL
        print("LL 旋轉")
        super().rotate_right(p)
      elif (bf < -1 and prevBalance < 0): # Case 2 RR
        print("RR 旋轉")
        super().rotate_left(p)
      elif (bf > 1 and prevBalance < 0): #  Case 3 LR
        print("LR 旋轉")
        super().rotate_left(p.left)
        super().rotate_right(p)
      elif (bf < -1 and prevBalance > 0): # Case 4 RL            
        print("RL 旋轉")
        super().rotate_right(p.right)
        super().rotate_left(p)
      prevBalance = bf
      p = p.parent

# %%
from IPython.core.display import DisplayObject
import time
import ipywidgets as widgets
from ipywidgets import BoundedIntText, Button, HTML, Tab, HBox, VBox, Output

###############################
# Input field for keys
ui_key = BoundedIntText(value=20, min=0, max=100, 
      step=2, description='輸入鍵值(0-100):', disabled=False)
################################
# Error messages
msg = "<p>接下列任一按鍵!</p>"
msg1 = "尚未建立二元樹!"
msg2 = "未找到所需鍵值!!"  
################################


# Create a new tree
tree = BST()
# Buttons
btn_insert = Button(description='新增', button_style='success')
def on_button_insert_clicked(b):
  with out:
    clear_output()
    tree.insert(ui_key.value)
    dot = BSTViz(tree).visualize(None)
    display(dot)       
btn_insert.on_click(on_button_insert_clicked)

btn_delete = Button(description='刪除', button_style='primary')
def on_button_delete_clicked(b):
  with out:
    if (tree.root is None):
      print(msg1)
    else:
      clear_output()
      tree.delete(ui_key.value)
      dot = BSTViz(tree).visualize(None)
      display(dot)

btn_delete.on_click(on_button_delete_clicked)

btn_reset = Button(description='清除二元樹', button_style='danger')
def on_button_reset_clicked(b):
  tree.root = None
  with out:
    clear_output()
    tree.root = None 
btn_reset.on_click(on_button_reset_clicked)

btn_search = Button(description='搜尋', button_style='info')
def on_button_search_clicked(b):
  with out:
    if (tree.root is None):
      print(msg1)
    else:
      clear_output()
      foundnode = tree.find(ui_key.value)
      if (foundnode != None):
        print("找到鍵值：" + foundnode.to_string())
        dot = BSTViz(tree).visualize(foundnode)
        display(dot)
      else:
        clear_output()
        print(msg2)                    
        dot = BSTViz(tree).visualize(None)
        display(dot)
btn_search.on_click(on_button_search_clicked)

btn_rnd = widgets.Button(description='隨機產生二元樹', button_style='warning')
seed(1) # Set the seed for the random number generator
def on_button_rnd_clicked(b):
  tree.root = None
  with out:
    clear_output()
    tree.root = None
    keys = randint(1, 90, 7)
    for key in keys:
      tree.insert(key)
    dot = BSTViz(tree).visualize(None)
    display(dot)
btn_rnd.on_click(on_button_rnd_clicked)

btn_inorder = widgets.Button(description='中序走訪', button_style='info')
seconds = int(time.time() * 1000) % 1000
seed(seconds) # Set the seed for the random number generator

################################
# Layout
layout_displ=Layout(height='550px', border='1px dotted blue', overflow ='auto')
layout_ctrl=Layout(height='30px')
################################

# Create a new AVL tree
avl = AVLTree()
# Buttons
btn_insert_avl = Button(description='新增', button_style='success')
def on_button_insert_avl_clicked(b):
  with out:
    clear_output()
    avl.insert(ui_key.value)
    dot = BSTViz(avl).visualize(None)
    display(dot)       
btn_insert_avl.on_click(on_button_insert_avl_clicked)

btn_delete_avl = Button(description='刪除', button_style='primary')
def on_button_delete_avl_clicked(b):
  with out:
    clear_output()
    avl.delete(ui_key.value)
    dot = BSTViz(avl).visualize(None)
    display(dot)        
btn_delete_avl.on_click(on_button_delete_avl_clicked)

btn_rnd_avl = Button(description='隨機產生AVL', button_style='warning')
seconds = int(time.time() * 1000) % 1000
seed(seconds) # Set the seed for the random number generator
def on_button_rnd_avl_clicked(b):
  with out:
    clear_output()
    avl.root = None
    keys = randint(1, 90, 7)
    for key in keys:    
      avl.insert(key)        
    dot = BSTViz(avl).visualize(None)
    display(dot)  
btn_rnd_avl.on_click(on_button_rnd_avl_clicked)

btn_clear_avl = Button(description='清除AVL', button_style='danger')
def on_button_clear_avl_clicke(b):
  avl.root = None
  with out:
    clear_output()
    avl.root = None 
btn_clear_avl.on_click(on_button_clear_avl_clicke)

################################
# Output objects
#######################

out = widgets.Output()
out.clear_output()

out1 = widgets.Output()
out1.clear_output()
with out1:
  msgbox = HTML("<p></p>")
  displ = HBox([out], layout=layout_displ)
  ctrl = HBox([ui_key, btn_insert, btn_delete, btn_search, btn_rnd, btn_reset], layout=layout_ctrl)
  display(VBox([displ, msgbox, ctrl]))

out2 = widgets.Output()
out2.clear_output()
with out2:
  msgbox = HTML("<p></p>")
  displ = HBox([out], layout=layout_displ)
  ctrl = HBox([ui_key, btn_insert_avl, btn_delete_avl, btn_rnd_avl, btn_clear_avl], layout=layout_ctrl)
  display(VBox([displ, msgbox, ctrl]))

def tab_change(change):
  out.clear_output()
  tree.root = None
  avl.root = None

tab = Tab(children = [out1, out2], layout=Layout(width='100%', height='auto'))
tab.set_title(0, '二元搜尋樹')
tab.set_title(1, '高度平衡樹 (AVL Tree)')
tab.observe(tab_change, names='selected_index')
display(tab)
